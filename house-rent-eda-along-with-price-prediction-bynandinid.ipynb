# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-price-dataset-of-india/House Price India.csv

# %% [markdown]
# # **Importing the necessary libraries for EDA and data preprocessing**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from scipy import stats

# %% [markdown]
# # **Converting csv file into dataframe**

# %%
df=pd.read_csv('/kaggle/input/house-price-dataset-of-india/House Price India.csv')

# %%
df=df.drop(['Date'],axis=1)

# %%
df
# Out:
#                id  number of bedrooms  number of bathrooms  living area  \
# 0      6762810145                   5                 2.50         3650
# 1      6762810635                   4                 2.50         2920
# 2      6762810998                   5                 2.75         2910
# 3      6762812605                   4                 2.50         3310
# 4      6762812919                   3                 2.00         2710
# ...           ...                 ...                  ...          ...
# 14615  6762830250                   2                 1.50         1556
# 14616  6762830339                   3                 2.00         1680
# 14617  6762830618                   2                 1.00         1070
# 14618  6762830709                   4                 1.00         1030
# 14619  6762831463                   3                 1.00          900
#
#        lot area  number of floors  waterfront present  number of views  \
# 0          9050               2.0                   0                4
# 1          4000               1.5                   0                0
# 2          9480               1.5                   0                0
# 3         42998               2.0                   0                0
# 4          4500               1.5                   0                0
# ...         ...               ...                 ...              ...
# 14615     20000               1.0                   0                0
# 14616      7000               1.5                   0                0
# 14617      6120               1.0                   0                0
# 14618      6621               1.0                   0                0
# 14619      4770               1.0                   0                0
#
#        condition of the house  grade of the house  ...  Built Year  \
# 0                           5                  10  ...        1921
# 1                           5                   8  ...        1909
# 2                           3                   8  ...        1939
# 3                           3                   9  ...        2001
# 4                           4                   8  ...        1929
# ...                       ...                 ...  ...         ...
# 14615                       4                   7  ...        1957
# 14616                       4                   7  ...        1968
# 14617                       3                   6  ...        1962
# 14618                       4                   6  ...        1955
# 14619                       3                   6  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                    0       122003    52.8645   -114.557               2880
# 1                    0       122004    52.8878   -114.470               2470
# 2                    0       122004    52.8852   -114.468               2940
# 3                    0       122005    52.9532   -114.321               3350
# 4                    0       122006    52.9047   -114.485               2060
# ...                ...          ...        ...        ...                ...
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0                5400                         2                         58
# 1                4000                         2                         51
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 0      2380000
# 1      1400000
# 2      1200000
# 3       838000
# 4       805000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [14620 rows x 22 columns]

# %%
df.head()
# Out:
#            id  number of bedrooms  number of bathrooms  living area  lot area  \
# 0  6762810145                   5                 2.50         3650      9050
# 1  6762810635                   4                 2.50         2920      4000
# 2  6762810998                   5                 2.75         2910      9480
# 3  6762812605                   4                 2.50         3310     42998
# 4  6762812919                   3                 2.00         2710      4500
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# 3               2.0                   0                0
# 4               1.5                   0                0
#
#    condition of the house  grade of the house  ...  Built Year  \
# 0                       5                  10  ...        1921
# 1                       5                   8  ...        1909
# 2                       3                   8  ...        1939
# 3                       3                   9  ...        2001
# 4                       4                   8  ...        1929
#
#    Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                0       122003    52.8645   -114.557               2880
# 1                0       122004    52.8878   -114.470               2470
# 2                0       122004    52.8852   -114.468               2940
# 3                0       122005    52.9532   -114.321               3350
# 4                0       122006    52.9047   -114.485               2060
#
#    lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0            5400                         2                         58
# 1            4000                         2                         51
# 2            6600                         1                         53
# 3           42847                         3                         76
# 4            4500                         1                         51
#
#      Price
# 0  2380000
# 1  1400000
# 2  1200000
# 3   838000
# 4   805000
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#                id  number of bedrooms  number of bathrooms  living area  \
# 14615  6762830250                   2                  1.5         1556
# 14616  6762830339                   3                  2.0         1680
# 14617  6762830618                   2                  1.0         1070
# 14618  6762830709                   4                  1.0         1030
# 14619  6762831463                   3                  1.0          900
#
#        lot area  number of floors  waterfront present  number of views  \
# 14615     20000               1.0                   0                0
# 14616      7000               1.5                   0                0
# 14617      6120               1.0                   0                0
# 14618      6621               1.0                   0                0
# 14619      4770               1.0                   0                0
#
#        condition of the house  grade of the house  ...  Built Year  \
# 14615                       4                   7  ...        1957
# 14616                       4                   7  ...        1968
# 14617                       3                   6  ...        1962
# 14618                       4                   6  ...        1955
# 14619                       3                   6  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#         Price
# 14615  221700
# 14616  219200
# 14617  209000
# 14618  205000
# 14619  146000
#
# [5 rows x 22 columns]

# %% [markdown]
# # **Checking for null and duplicated values**

# %%
df.isna().sum()
# Out:
# id                                       0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# Price                                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   number of bedrooms                     14620 non-null  int64
#  2   number of bathrooms                    14620 non-null  float64
#  3   living area                            14620 non-null  int64
#  4   lot area                               14620 non-null  int64
#  5   number of floors                       14620 non-null  float64
#  6   waterfront present                     14620 non-null  int64
#  7   number of views                        14620 non-null  int64
#  8   condition of the house                 14620 non-null  int64
#  9   grade of the house                     14620 non-null  int64
#  10  Area of the house(excluding basement)  14620 non-null  int64
#  11  Area of the basement                   14620 non-null  int64
#  12  Built Year                             14620 non-null  int64
#  13  Renovation Year                        14620 non-null  int64
#  14  Postal Code                            14620 non-null  int64
#  15  Lattitude                              14620 non-null  float64
#  16  Longitude                              14620 non-null  float64
#  17  living_area_renov                      14620 non-null  int64
#  18  lot_area_renov                         14620 non-null  int64
#  19  Number of schools nearby               14620 non-null  int64
#  20  Distance from the airport              14620 non-null  int64
#  21  Price                                  14620 non-null  int64
# dtypes: float64(4), int64(18)
# memory usage: 2.5 MB

# %%
df.describe()
# Out:
#                  id  number of bedrooms  number of bathrooms   living area  \
# count  1.462000e+04        14620.000000         14620.000000  14620.000000
# mean   6.762821e+09            3.379343             2.129583   2098.262996
# std    6.237575e+03            0.938719             0.769934    928.275721
# min    6.762810e+09            1.000000             0.500000    370.000000
# 25%    6.762815e+09            3.000000             1.750000   1440.000000
# 50%    6.762821e+09            3.000000             2.250000   1930.000000
# 75%    6.762826e+09            4.000000             2.500000   2570.000000
# max    6.762832e+09           33.000000             8.000000  13540.000000
#
#            lot area  number of floors  waterfront present  number of views  \
# count  1.462000e+04      14620.000000        14620.000000     14620.000000
# mean   1.509328e+04          1.502360            0.007661         0.233105
# std    3.791962e+04          0.540239            0.087193         0.766259
# min    5.200000e+02          1.000000            0.000000         0.000000
# 25%    5.010750e+03          1.000000            0.000000         0.000000
# 50%    7.620000e+03          1.500000            0.000000         0.000000
# 75%    1.080000e+04          2.000000            0.000000         0.000000
# max    1.074218e+06          3.500000            1.000000         4.000000
#
#        condition of the house  grade of the house  ...    Built Year  \
# count            14620.000000        14620.000000  ...  14620.000000
# mean                 3.430506            7.682421  ...   1970.926402
# std                  0.664151            1.175033  ...     29.493625
# min                  1.000000            4.000000  ...   1900.000000
# 25%                  3.000000            7.000000  ...   1951.000000
# 50%                  3.000000            7.000000  ...   1975.000000
# 75%                  4.000000            8.000000  ...   1997.000000
# max                  5.000000           13.000000  ...   2015.000000
#
#        Renovation Year    Postal Code     Lattitude     Longitude  \
# count     14620.000000   14620.000000  14620.000000  14620.000000
# mean         90.924008  122033.062244     52.792848   -114.404007
# std         416.216661      19.082418      0.137522      0.141326
# min           0.000000  122003.000000     52.385900   -114.709000
# 25%           0.000000  122017.000000     52.707600   -114.519000
# 50%           0.000000  122032.000000     52.806400   -114.421000
# 75%           0.000000  122048.000000     52.908900   -114.315000
# max        2015.000000  122072.000000     53.007600   -113.505000
#
#        living_area_renov  lot_area_renov  Number of schools nearby  \
# count       14620.000000    14620.000000              14620.000000
# mean         1996.702257    12753.500068                  2.012244
# std           691.093366    26058.414467                  0.817284
# min           460.000000      651.000000                  1.000000
# 25%          1490.000000     5097.750000                  1.000000
# 50%          1850.000000     7620.000000                  2.000000
# 75%          2380.000000    10125.000000                  3.000000
# max          6110.000000   560617.000000                  3.000000
#
#        Distance from the airport         Price
# count               14620.000000  1.462000e+04
# mean                   64.950958  5.389322e+05
# std                     8.936008  3.675324e+05
# min                    50.000000  7.800000e+04
# 25%                    57.000000  3.200000e+05
# 50%                    65.000000  4.500000e+05
# 75%                    73.000000  6.450000e+05
# max                    80.000000  7.700000e+06
#
# [8 rows x 22 columns]

# %% [markdown]
# # **Checking for outliers**

# %%
sns.boxplot(df['number of bedrooms'])
# Out:
# <AxesSubplot:>

# %%
z=np.abs(stats.zscore(df['number of bedrooms']))

# %%
threshold=3
print(np.where(z>3),len(np.where(z>3)[0]))
# Out:
# (array([   76,   243,   268,   275,   624,   785,  1512,  1519,  1553,
#         1706,  2814,  3109,  3114,  3322,  3532,  3600,  4207,  4486,
#         4658,  4680,  6591,  6596,  6730,  6982,  6998,  7003,  7454,
#         8559,  8650,  9282,  9629,  9810,  9955, 10168, 10177, 10676,
#        10748, 10916, 10944, 11247, 11441, 11547, 11877, 12273, 13048,
#        13444, 13825, 14220, 14481]),) 49

# %%
print(np.where(z<-3))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# # **There are 138 outliers in number of bedrooms as proved from the boxplot and the fact that there are observations whose z-score is beyond 3**

# %%
df1=df[(z< 3)]

# %%
sns.boxplot(df1['number of bedrooms'])
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#                id  number of bedrooms  number of bathrooms  living area  \
# 0      6762810145                   5                 2.50         3650
# 1      6762810635                   4                 2.50         2920
# 2      6762810998                   5                 2.75         2910
# 3      6762812605                   4                 2.50         3310
# 4      6762812919                   3                 2.00         2710
# ...           ...                 ...                  ...          ...
# 14615  6762830250                   2                 1.50         1556
# 14616  6762830339                   3                 2.00         1680
# 14617  6762830618                   2                 1.00         1070
# 14618  6762830709                   4                 1.00         1030
# 14619  6762831463                   3                 1.00          900
#
#        lot area  number of floors  waterfront present  number of views  \
# 0          9050               2.0                   0                4
# 1          4000               1.5                   0                0
# 2          9480               1.5                   0                0
# 3         42998               2.0                   0                0
# 4          4500               1.5                   0                0
# ...         ...               ...                 ...              ...
# 14615     20000               1.0                   0                0
# 14616      7000               1.5                   0                0
# 14617      6120               1.0                   0                0
# 14618      6621               1.0                   0                0
# 14619      4770               1.0                   0                0
#
#        condition of the house  grade of the house  ...  Built Year  \
# 0                           5                  10  ...        1921
# 1                           5                   8  ...        1909
# 2                           3                   8  ...        1939
# 3                           3                   9  ...        2001
# 4                           4                   8  ...        1929
# ...                       ...                 ...  ...         ...
# 14615                       4                   7  ...        1957
# 14616                       4                   7  ...        1968
# 14617                       3                   6  ...        1962
# 14618                       4                   6  ...        1955
# 14619                       3                   6  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                    0       122003    52.8645   -114.557               2880
# 1                    0       122004    52.8878   -114.470               2470
# 2                    0       122004    52.8852   -114.468               2940
# 3                    0       122005    52.9532   -114.321               3350
# 4                    0       122006    52.9047   -114.485               2060
# ...                ...          ...        ...        ...                ...
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0                5400                         2                         58
# 1                4000                         2                         51
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 0      2380000
# 1      1400000
# 2      1200000
# 3       838000
# 4       805000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [14571 rows x 22 columns]

# %%
sns.boxplot(df1['number of bathrooms'])
# Out:
# <AxesSubplot:>

# %%
z=np.abs(stats.zscore(df1['number of bathrooms']))

# %%
len(np.where(z>3)[0])
# Out:
# 124

# %%
print(np.where(z<-3))
# Out:
# (array([], dtype=int64),)

# %%
df1=df1[(z< 3)]

# %%
sns.boxplot(df1['number of bathrooms'])
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#                id  number of bedrooms  number of bathrooms  living area  \
# 0      6762810145                   5                 2.50         3650
# 1      6762810635                   4                 2.50         2920
# 2      6762810998                   5                 2.75         2910
# 3      6762812605                   4                 2.50         3310
# 4      6762812919                   3                 2.00         2710
# ...           ...                 ...                  ...          ...
# 14615  6762830250                   2                 1.50         1556
# 14616  6762830339                   3                 2.00         1680
# 14617  6762830618                   2                 1.00         1070
# 14618  6762830709                   4                 1.00         1030
# 14619  6762831463                   3                 1.00          900
#
#        lot area  number of floors  waterfront present  number of views  \
# 0          9050               2.0                   0                4
# 1          4000               1.5                   0                0
# 2          9480               1.5                   0                0
# 3         42998               2.0                   0                0
# 4          4500               1.5                   0                0
# ...         ...               ...                 ...              ...
# 14615     20000               1.0                   0                0
# 14616      7000               1.5                   0                0
# 14617      6120               1.0                   0                0
# 14618      6621               1.0                   0                0
# 14619      4770               1.0                   0                0
#
#        condition of the house  grade of the house  ...  Built Year  \
# 0                           5                  10  ...        1921
# 1                           5                   8  ...        1909
# 2                           3                   8  ...        1939
# 3                           3                   9  ...        2001
# 4                           4                   8  ...        1929
# ...                       ...                 ...  ...         ...
# 14615                       4                   7  ...        1957
# 14616                       4                   7  ...        1968
# 14617                       3                   6  ...        1962
# 14618                       4                   6  ...        1955
# 14619                       3                   6  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                    0       122003    52.8645   -114.557               2880
# 1                    0       122004    52.8878   -114.470               2470
# 2                    0       122004    52.8852   -114.468               2940
# 3                    0       122005    52.9532   -114.321               3350
# 4                    0       122006    52.9047   -114.485               2060
# ...                ...          ...        ...        ...                ...
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0                5400                         2                         58
# 1                4000                         2                         51
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 0      2380000
# 1      1400000
# 2      1200000
# 3       838000
# 4       805000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [14447 rows x 22 columns]

# %% [markdown]
# # **There are 124 outliers in number of bathrooms as proved from the boxplot and the fact that there are observations whose z-score is beyond 3**

# %%
sns.boxplot(df1['living area'])
# Out:
# <AxesSubplot:>

# %%
z=np.abs(stats.zscore(df1['living area']))

# %%
len(np.where(z>3)[0])
# Out:
# 136

# %%
len(np.where(z<-3)[0])
# Out:
# 0

# %%
df1=df1[(z<3)]

# %%
sns.boxplot(df1['living area'])
# Out:
# <AxesSubplot:>

# %%
z=np.abs(stats.zscore(df1['living area']))

# %%
len(np.where(z>3)[0])
# Out:
# 67

# %%
df1=df1[(z<3)]

# %%
sns.boxplot(df1['living area'])
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#                id  number of bedrooms  number of bathrooms  living area  \
# 0      6762810145                   5                 2.50         3650
# 1      6762810635                   4                 2.50         2920
# 2      6762810998                   5                 2.75         2910
# 3      6762812605                   4                 2.50         3310
# 4      6762812919                   3                 2.00         2710
# ...           ...                 ...                  ...          ...
# 14615  6762830250                   2                 1.50         1556
# 14616  6762830339                   3                 2.00         1680
# 14617  6762830618                   2                 1.00         1070
# 14618  6762830709                   4                 1.00         1030
# 14619  6762831463                   3                 1.00          900
#
#        lot area  number of floors  waterfront present  number of views  \
# 0          9050               2.0                   0                4
# 1          4000               1.5                   0                0
# 2          9480               1.5                   0                0
# 3         42998               2.0                   0                0
# 4          4500               1.5                   0                0
# ...         ...               ...                 ...              ...
# 14615     20000               1.0                   0                0
# 14616      7000               1.5                   0                0
# 14617      6120               1.0                   0                0
# 14618      6621               1.0                   0                0
# 14619      4770               1.0                   0                0
#
#        condition of the house  grade of the house  ...  Built Year  \
# 0                           5                  10  ...        1921
# 1                           5                   8  ...        1909
# 2                           3                   8  ...        1939
# 3                           3                   9  ...        2001
# 4                           4                   8  ...        1929
# ...                       ...                 ...  ...         ...
# 14615                       4                   7  ...        1957
# 14616                       4                   7  ...        1968
# 14617                       3                   6  ...        1962
# 14618                       4                   6  ...        1955
# 14619                       3                   6  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                    0       122003    52.8645   -114.557               2880
# 1                    0       122004    52.8878   -114.470               2470
# 2                    0       122004    52.8852   -114.468               2940
# 3                    0       122005    52.9532   -114.321               3350
# 4                    0       122006    52.9047   -114.485               2060
# ...                ...          ...        ...        ...                ...
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0                5400                         2                         58
# 1                4000                         2                         51
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 0      2380000
# 1      1400000
# 2      1200000
# 3       838000
# 4       805000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [14244 rows x 22 columns]

# %% [markdown]
# # **There are 205 outliers in living as proved from the boxplot and the fact that there are observations whose z-score is beyond 3**

# %%
sns.boxplot(df1['number of floors'])
# Out:
# <AxesSubplot:>

# %%
z=np.abs(stats.zscore(df1['number of floors']))

# %%
len(np.where(z>3)[0])
# Out:
# 3

# %%
df1=df1[(z<3)]

# %%
sns.boxplot(df1['number of floors'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **There are 3 outliers in number of floors**

# %%
sns.boxplot(df1['Price'])
# Out:
# <AxesSubplot:>

# %%
z=np.abs(stats.zscore(df1['Price']))

# %%
len(np.where(z>3)[0])
# Out:
# 259

# %%
df1=df1[(z<3)]

# %%
df1
# Out:
#                id  number of bedrooms  number of bathrooms  living area  \
# 2      6762810998                   5                 2.75         2910
# 3      6762812605                   4                 2.50         3310
# 4      6762812919                   3                 2.00         2710
# 5      6762813105                   3                 2.50         2600
# 6      6762813157                   5                 3.25         3660
# ...           ...                 ...                  ...          ...
# 14615  6762830250                   2                 1.50         1556
# 14616  6762830339                   3                 2.00         1680
# 14617  6762830618                   2                 1.00         1070
# 14618  6762830709                   4                 1.00         1030
# 14619  6762831463                   3                 1.00          900
#
#        lot area  number of floors  waterfront present  number of views  \
# 2          9480               1.5                   0                0
# 3         42998               2.0                   0                0
# 4          4500               1.5                   0                0
# 5          4750               1.0                   0                0
# 6         11995               2.0                   0                2
# ...         ...               ...                 ...              ...
# 14615     20000               1.0                   0                0
# 14616      7000               1.5                   0                0
# 14617      6120               1.0                   0                0
# 14618      6621               1.0                   0                0
# 14619      4770               1.0                   0                0
#
#        condition of the house  grade of the house  ...  Built Year  \
# 2                           3                   8  ...        1939
# 3                           3                   9  ...        2001
# 4                           4                   8  ...        1929
# 5                           4                   9  ...        1951
# 6                           3                  10  ...        2006
# ...                       ...                 ...  ...         ...
# 14615                       4                   7  ...        1957
# 14616                       4                   7  ...        1968
# 14617                       3                   6  ...        1962
# 14618                       4                   6  ...        1955
# 14619                       3                   6  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 2                    0       122004    52.8852   -114.468               2940
# 3                    0       122005    52.9532   -114.321               3350
# 4                    0       122006    52.9047   -114.485               2060
# 5                    0       122007    52.9133   -114.590               2380
# 6                    0       122008    52.7637   -114.050               3320
# ...                ...          ...        ...        ...                ...
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# 5                4750                         1                         67
# 6               11241                         3                         72
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 2      1200000
# 3       838000
# 4       805000
# 5       790000
# 6       785000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [13982 rows x 22 columns]

# %%
df1=df1.drop(['Renovation Year'],axis=1)

# %%
df1
# Out:
#                id  number of bedrooms  number of bathrooms  living area  \
# 2      6762810998                   5                 2.75         2910
# 3      6762812605                   4                 2.50         3310
# 4      6762812919                   3                 2.00         2710
# 5      6762813105                   3                 2.50         2600
# 6      6762813157                   5                 3.25         3660
# ...           ...                 ...                  ...          ...
# 14615  6762830250                   2                 1.50         1556
# 14616  6762830339                   3                 2.00         1680
# 14617  6762830618                   2                 1.00         1070
# 14618  6762830709                   4                 1.00         1030
# 14619  6762831463                   3                 1.00          900
#
#        lot area  number of floors  waterfront present  number of views  \
# 2          9480               1.5                   0                0
# 3         42998               2.0                   0                0
# 4          4500               1.5                   0                0
# 5          4750               1.0                   0                0
# 6         11995               2.0                   0                2
# ...         ...               ...                 ...              ...
# 14615     20000               1.0                   0                0
# 14616      7000               1.5                   0                0
# 14617      6120               1.0                   0                0
# 14618      6621               1.0                   0                0
# 14619      4770               1.0                   0                0
#
#        condition of the house  grade of the house  ...  Area of the basement  \
# 2                           3                   8  ...                     0
# 3                           3                   9  ...                     0
# 4                           4                   8  ...                   830
# 5                           4                   9  ...                   900
# 6                           3                  10  ...                     0
# ...                       ...                 ...  ...                   ...
# 14615                       4                   7  ...                     0
# 14616                       4                   7  ...                     0
# 14617                       3                   6  ...                     0
# 14618                       4                   6  ...                     0
# 14619                       3                   6  ...                     0
#
#        Built Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 2            1939       122004    52.8852   -114.468               2940
# 3            2001       122005    52.9532   -114.321               3350
# 4            1929       122006    52.9047   -114.485               2060
# 5            1951       122007    52.9133   -114.590               2380
# 6            2006       122008    52.7637   -114.050               3320
# ...           ...          ...        ...        ...                ...
# 14615        1957       122066    52.6191   -114.472               2250
# 14616        1968       122072    52.5075   -114.393               1540
# 14617        1962       122056    52.7289   -114.507               1130
# 14618        1955       122042    52.7157   -114.411               1420
# 14619        1969       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# 5                4750                         1                         67
# 6               11241                         3                         72
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 2      1200000
# 3       838000
# 4       805000
# 5       790000
# 6       785000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [13982 rows x 21 columns]

# %% [markdown]
# # **The column Renovation year have been removed. This is because most of the Renovation Year are 0 and  proves to be of no use to the model**

# %%
sns.barplot(data=df1,x='number of bedrooms',y='Price')
# Out:
# <AxesSubplot:xlabel='number of bedrooms', ylabel='Price'>

# %% [markdown]
# # **Clear indication of Price increasing with number of bedrooms**

# %%
sns.barplot(data=df1,x='number of bathrooms',y='Price')
# Out:
# <AxesSubplot:xlabel='number of bathrooms', ylabel='Price'>

# %% [markdown]
# # **Clear indication of Price increasing with number of bathrooms**

# %%
plt.figure(figsize=(12,18))
sns.countplot(data=df1,y='Built Year')
plt.show()

# %% [markdown]
# # **Most of the houses were listed for sale in 2017**

# %%
plt.figure(figsize=(12,18))
sns.countplot(data=df1,y='Postal Code')
plt.show()

# %% [markdown]
# # **Most of the houses listed for sale are from the Pincode 122028**

# %%
df1[df1['Built Year']==2014]['Lattitude'].mean()
# Out:
# 52.77583376963351

# %%
df1[df1['Built Year']==2014]['Longitude'].mean()
# Out:
# -114.38898952879582

# %%
m = folium.Map(location = [52.77, -114.4], tiles ='OpenStreetMap',      
    zoom_start=8)

for index, location_info in df1[(df1['Built Year']==2014) & (df1['Distance from the airport']<=70)].iterrows():
    folium.Marker([location_info["Lattitude"], location_info["Longitude"]], popup=location_info["Price"],icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75bb175c3c0d5e6609c9383a518b96c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75bb175c3c0d5e6609c9383a518b96c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75bb175c3c0d5e6609c9383a518b96c7 = L.map(
#                 &quot;map_75bb175c3c0d5e6609c9383a518b96c7&quot;,
#                 {
#                     center: [52.77, -114.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab3c447eb6e2ad9f266753c2df0c89b6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_75bb175c3c0d5e6609c9383a518b96c7);
#
#
#             var marker_f470a4f4075b5f6c833feb5d5f818d3d = L.marker(
#                 [52.9838, -114.515],
#                 {}
#             ).addTo(map_75bb175c3c0d5e6609c9383a518b96c7);
#
#
#             var icon_9afafcbd4263fab30db28ae68652fca8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f470a4f4075b5f6c833feb5d5f818d3d.setIcon(icon_9afafcbd4263fab30db28ae68652fca8);
#
#
#         var popup_6d2284dab10feeef8a4945f2f7386614 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5581f4bfe8969506a588d3305e3e9dd = $(`&lt;div id=&quot;html_e5581f4bfe8969506a588d3305e3e9dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;625000.0&lt;/div&gt;`)[0];
#                 popup_6d2284dab10feeef8a4945f2f7386614.setContent(html_e5581f4bfe8969506a588d3305e3e9dd);
#
#
#
#         marker_f470a4f4075b5f6c833feb5d5f818d3d.bindPopup(popup_6d2284dab10feeef8a4945f2f7386614)
#         ;
#
#
#
#
#             var marker_106b017738096a3dcc4131272e8cfeac = L.marker(
#                 [52.9097, -114.575],
#                 {}
#             ).addTo(map_75bb175c3c0d5e6609c9383a518b96c7);
#
#
#             var icon_e0784402ef3ea7d663e30a238f764fcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_106b017738096a3dcc4131272e8cfeac.setIcon(icon_e0784402ef3ea7d663e30a238f764fcf);
#
#
#         var popup_64771c615045eed4bb57f2cf6e575756 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d3c49d2c38bfb02fc39cbbf40d57176 = $(`&lt;div id=&quot;html_3d3c49d2c38bfb02fc39cbbf40d57176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;979000.0&lt;/div&gt;`)[0];
#                 popup_64771c615045eed4bb57f2cf6e575756.setContent(html_3d3c49d2c38bfb02fc39cbbf40d57176);
#
#
#
#         marker_106b017738096a3dcc4131272e8cfeac.bindPopup(popup_64771c615045eed4bb57f2cf6e575756)
#         ;
#
#
#
#
#             var marker_14b6f4934bad6bfb64ad310e2b39a531 = L.marker(
#                 [52.8872, -114.536],
#                 {}
#             ).addTo(map_75bb175c3c0d5e6609c9383a518b96c7);
#
#
#             var icon_590f006419bd7a50fc7d99eb4b868774 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_14b6f4934bad6bfb64ad310e2b39a531.setIcon(icon_590f006419bd7a50fc7d99eb4b868774);
#
#
#         var popup_9ba2006b748176b53453e7b294daa8a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e1251bfb748e29db8723b126c4d7089 = $(`&lt;div id=&quot;html_1e1251bfb748e29db8723b126c4d7089&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;610950.0&lt;/div&gt;`)[0];
#                 popup_9ba2006b748176b53453e7b294daa8a9.setContent(html_1e1251bfb748e29db8723b126c4d7089);
#
#
#
#         marker_14b6f4934bad6bfb64ad310e2b39a531.bindPopup(popup_9ba2006b748176b53453e7b294daa8a9)
#         ;
#
#
#
#
#             var marker_de14775a843d5cdeaafe93ddf54e3681 = L.marker(
#                 [52.9022, -114.571],
#                 {}
#             ).addTo(map_75bb175c3c0d5e6609c9383a518b96c7);
#
#
#             var icon_de8e72f9d2516d39a72f42f078871a1e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;:

# %%
df1[df1['Built Year']>=2014]['Lattitude'].mean()
# Out:
# 52.77850305343512

# %%
df1[df1['Built Year']>=2014]['Longitude'].mean()
# Out:
# -114.39186768447837

# %%
m = folium.Map(location = [52.77, -114.4], tiles ='OpenStreetMap',      
    zoom_start=8)

for index, location_info in df1[(df1['Built Year']>=2014) & (df1['Distance from the airport']<=70)].iterrows():
    folium.Marker([location_info["Lattitude"], location_info["Longitude"]], popup=location_info["Price"],icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a15a9e614854b26f6f7b6d6fbe22669c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a15a9e614854b26f6f7b6d6fbe22669c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a15a9e614854b26f6f7b6d6fbe22669c = L.map(
#                 &quot;map_a15a9e614854b26f6f7b6d6fbe22669c&quot;,
#                 {
#                     center: [52.77, -114.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2dde122ed07fed67f8254f8ee7ae1f89 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a15a9e614854b26f6f7b6d6fbe22669c);
#
#
#             var marker_7ae83c6645986830c264025209f2e613 = L.marker(
#                 [52.9838, -114.515],
#                 {}
#             ).addTo(map_a15a9e614854b26f6f7b6d6fbe22669c);
#
#
#             var icon_e69b2d9579d3559a8edd746115768ddb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ae83c6645986830c264025209f2e613.setIcon(icon_e69b2d9579d3559a8edd746115768ddb);
#
#
#         var popup_ee42b3630c68ba6df001a1be7c60bb91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f27c48f2feebc0d4c490c4aae68ed092 = $(`&lt;div id=&quot;html_f27c48f2feebc0d4c490c4aae68ed092&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;625000.0&lt;/div&gt;`)[0];
#                 popup_ee42b3630c68ba6df001a1be7c60bb91.setContent(html_f27c48f2feebc0d4c490c4aae68ed092);
#
#
#
#         marker_7ae83c6645986830c264025209f2e613.bindPopup(popup_ee42b3630c68ba6df001a1be7c60bb91)
#         ;
#
#
#
#
#             var marker_6483d822af7c30c0c59d1aac38ab807b = L.marker(
#                 [52.9097, -114.575],
#                 {}
#             ).addTo(map_a15a9e614854b26f6f7b6d6fbe22669c);
#
#
#             var icon_35178a7071db28290646449cb9756158 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6483d822af7c30c0c59d1aac38ab807b.setIcon(icon_35178a7071db28290646449cb9756158);
#
#
#         var popup_65afef8ba44385297e448bb6df654cad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc16b49a95a99bdd8e84176fe08f82d3 = $(`&lt;div id=&quot;html_bc16b49a95a99bdd8e84176fe08f82d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;979000.0&lt;/div&gt;`)[0];
#                 popup_65afef8ba44385297e448bb6df654cad.setContent(html_bc16b49a95a99bdd8e84176fe08f82d3);
#
#
#
#         marker_6483d822af7c30c0c59d1aac38ab807b.bindPopup(popup_65afef8ba44385297e448bb6df654cad)
#         ;
#
#
#
#
#             var marker_d13207a34453135dd1550dd97ad5943d = L.marker(
#                 [52.8872, -114.536],
#                 {}
#             ).addTo(map_a15a9e614854b26f6f7b6d6fbe22669c);
#
#
#             var icon_09105207de21f3f95a161d8809a4bd82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d13207a34453135dd1550dd97ad5943d.setIcon(icon_09105207de21f3f95a161d8809a4bd82);
#
#
#         var popup_a1d0313e24b2b13c56aff927f168cf5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db5cde926176847ddf239fa4ecfe37e9 = $(`&lt;div id=&quot;html_db5cde926176847ddf239fa4ecfe37e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;610950.0&lt;/div&gt;`)[0];
#                 popup_a1d0313e24b2b13c56aff927f168cf5c.setContent(html_db5cde926176847ddf239fa4ecfe37e9);
#
#
#
#         marker_d13207a34453135dd1550dd97ad5943d.bindPopup(popup_a1d0313e24b2b13c56aff927f168cf5c)
#         ;
#
#
#
#
#             var marker_cfb577498862c2255e7e9421b1cd8fed = L.marker(
#                 [52.9022, -114.571],
#                 {}
#             ).addTo(map_a15a9e614854b26f6f7b6d6fbe22669c);
#
#
#             var icon_a3607688629975fc4a993c7fa4bd3b08 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;:

# %% [markdown]
# # **The houses listed for sale in this dataset are located in Alberta, Canada**

# %%
df1=df1.drop(['id'],axis=1)

# %%
df1=df1.drop(['Postal Code'],axis=1)

# %% [markdown]
# # **Columns ID and Postal Code have been dropped from df as an increase or decrease in Postal Code shall not directly impact the Price of the property**

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df1.corr(),linewidths=0.5,annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# # **Columns like 'lot area','condition of the house','Built Year','lot_area_renov','Number of schools nearby','Distance from the airport','Longitude' contribute minimal to Price which is the Target variable. Hence it is removed before training**

# %%
df1=df1.drop(['lot area','condition of the house','Built Year','lot_area_renov','Number of schools nearby','Distance from the airport','Longitude'],axis=1)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df1.corr(),linewidths=0.5,annot=True,cmap='Blues')
plt.show()

# %% [markdown]
#  # **Training of Model, Splitting of Dataset into Train and Test Set**

# %%
from sklearn.model_selection import train_test_split

# %%
X=df1.drop(['Price'],axis =1)

# %%
X.shape
# Out:
# (13982, 11)

# %%
y=df1['Price']

# %%
y.shape
# Out:
# (13982,)

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=11)

# %%
X_train.shape
# Out:
# (11185, 11)

# %%
X_test.shape
# Out:
# (2797, 11)

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import ElasticNet, Lasso,LinearRegression,RidgeCV
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.svm import SVR

# %%
pipelines = {
    'en':make_pipeline(StandardScaler(), ElasticNet()),
    'lasso':make_pipeline(StandardScaler(), Lasso()),
    'Rcv':make_pipeline(StandardScaler(), RidgeCV()),
    'CatB':make_pipeline(StandardScaler(), CatBoostRegressor(eval_metric='RMSE',verbose=1000)),
    'lr':make_pipeline(StandardScaler(), LinearRegression()),
    'rf':make_pipeline(StandardScaler(), RandomForestRegressor()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingRegressor()),
    'dtc':make_pipeline(StandardScaler(),DecisionTreeRegressor()),
    'xg':make_pipeline(StandardScaler(),XGBRegressor())
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.781e+12, tolerance: 5.929e+10
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Learning rate set to 0.05996
# 0:	learn: 221490.1496581	total: 61.5ms	remaining: 1m 1s
# 999:	learn: 77595.2298921	total: 2.92s	remaining: 0us

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
maes=[]
al=[]
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    al.append(algo)
    maes.append(mean_squared_error(y_test,yhat)**0.5)
    print(algo,'MEAN ABSOLUTE ERROR', mean_absolute_error(y_test,yhat))
    print(algo,'ROOT MEAN SQUARED ERROR',mean_squared_error(y_test,yhat)**0.5)
# Out:
# en MEAN ABSOLUTE ERROR 104444.32355671145
# en ROOT MEAN SQUARED ERROR 140011.53917862213
# lasso MEAN ABSOLUTE ERROR 97479.23118789196
# lasso ROOT MEAN SQUARED ERROR 132916.1566456281
# Rcv MEAN ABSOLUTE ERROR 97481.91673717603
# Rcv ROOT MEAN SQUARED ERROR 132918.333682342
# CatB MEAN ABSOLUTE ERROR 66637.30790160663
# CatB ROOT MEAN SQUARED ERROR 97508.34029611414
# lr MEAN ABSOLUTE ERROR 97574.48622571728
# lr ROOT MEAN SQUARED ERROR 132952.7515959945
# rf MEAN ABSOLUTE ERROR 69266.7277052965
# rf ROOT MEAN SQUARED ERROR 101999.11018417288
# gb MEAN ABSOLUTE ERROR 69870.54488635932
# gb ROOT MEAN SQUARED ERROR 101051.67208108243
# dtc MEAN ABSOLUTE ERROR 96813.43385770469
# dtc ROOT MEAN SQUARED ERROR 144051.42771435322
# xg MEAN ABSOLUTE ERROR 69035.05210660976
# xg ROOT MEAN SQUARED ERROR 100694.41040458805

# %%
plt.figure(figsize=(5,5))
plt.xlabel('ML Algorithms...')
plt.ylabel('Root Mean Squared Errors...')
ax=sns.barplot(x=al,y=maes)
plt.show()

# %%
CatB = CatBoostRegressor(verbose=1000,eval_metric='RMSE')
rf = RandomForestRegressor()
gb = GradientBoostingRegressor()
xg = XGBRegressor()
lr=LinearRegression()

stregr = StackingRegressor(estimators=[('catb',CatB),('xg', xg),('gb',gb)],
                           final_estimator=lr)

pipeline = make_pipeline(
    StandardScaler(),
    stregr
)
pipeline.fit(X_train, y_train)

# Generate predictions on the test set
y_pred = pipeline.predict(X_test)

# Evaluate the model
print("Root Mean Squared Error: %.4f" % mean_squared_error(y_test,y_pred)**0.5)
# Out:
# Learning rate set to 0.05996
# 0:	learn: 221490.1496581	total: 4.66ms	remaining: 4.66s
# 999:	learn: 77595.2298921	total: 2.88s	remaining: 0us
# Learning rate set to 0.057883
# 0:	learn: 222091.4863333	total: 3.35ms	remaining: 3.35s
# 999:	learn: 76337.1933964	total: 2.55s	remaining: 0us
# Learning rate set to 0.057883
# 0:	learn: 222546.8538661	total: 3.18ms	remaining: 3.17s
# 999:	learn: 75466.5961681	total: 2.58s	remaining: 0us
# Learning rate set to 0.057883
# 0:	learn: 223455.5230951	total: 2.97ms	remaining: 2.97s
# 999:	learn: 75656.3661258	total: 2.64s	remaining: 0us
# Learning rate set to 0.057883
# 0:	learn: 221606.9467960	total: 2.9ms	remaining: 2.89s
# 999:	learn: 75195.9699196	total: 2.6s	remaining: 0us
# Learning rate set to 0.057883
# 0:	learn: 219316.0911020	total: 2.7ms	remaining: 2.69s
# 999:	learn: 74522.7989238	total: 2.56s	remaining: 0us
# Root Mean Squared Error: 96977.1365

# %%
mean_squared_error(y_test,y_pred)**0.5
# Out:
# 96977.13654784905

# %%
al.append('stacked model')
maes.append(mean_squared_error(y_test,y_pred)**0.5)

# %%
for i in range(10):
    print("The RMSE of",al[i],'is',maes[i])
# Out:
# The RMSE of en is 140011.53917862213
# The RMSE of lasso is 132916.1566456281
# The RMSE of Rcv is 132918.333682342
# The RMSE of CatB is 97508.34029611414
# The RMSE of lr is 132952.7515959945
# The RMSE of rf is 101999.11018417288
# The RMSE of gb is 101051.67208108243
# The RMSE of dtc is 144051.42771435322
# The RMSE of xg is 100694.41040458805
# The RMSE of stacked model is 96977.13654784905

# %%
plt.figure(figsize=(9,5))
plt.xlabel('ML Algorithms...')
plt.ylabel('Root Mean Squared Errors...')
ax=sns.barplot(x=al,y=maes)
plt.show()

# %% [markdown]
# # **The Stacked Model has an edge over the rest of the models due to lower RMSE**

# %% [markdown]
# **Do upvote the notebook if you find the work worthy!**
